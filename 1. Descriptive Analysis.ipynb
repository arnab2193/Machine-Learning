# %%
import pandas as pd
ipl_auction_df= pd.read_csv('IPL IMB381IPL2013.csv')

# %%
ipl_auction_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
type(ipl_auction_df)
# Out:
# pandas.core.frame.DataFrame

# %%
ipl_auction_df.shape
# Out:
# (130, 26)

# %%
pd.set_option('display.max_columns', 8)
ipl_auction_df.head(10)
# Out:
#    Sl.NO.    PLAYER NAME  AGE COUNTRY  ...  SR-BL AUCTION YEAR  BASE PRICE  \
# 0       1    Abdulla, YA    2      SA  ...  13.93         2009       50000
# 1       2   Abdur Razzak    2     BAN  ...   0.00         2008       50000
# 2       3    Agarkar, AB    2     IND  ...  24.90         2008      200000
# 3       4      Ashwin, R    1     IND  ...  22.14         2011      100000
# 4       5   Badrinath, S    2     IND  ...   0.00         2011      100000
# 5       6     Bailey, GJ    2     AUS  ...   0.00         2009       50000
# 6       7      Balaji, L    2     IND  ...  19.40         2011      100000
# 7       8  Bollinger, DE    2     AUS  ...  15.57         2011      200000
# 8       9       Botha, J    2      SA  ...  28.11         2011      200000
# 9      10    Boucher, MV    2      SA  ...   0.00         2008      200000
#
#    SOLD PRICE
# 0       50000
# 1       50000
# 2      350000
# 3      850000
# 4      800000
# 5       50000
# 6      500000
# 7      700000
# ...

# %%
list(ipl_auction_df.columns)
# Out:
# ['Sl.NO.',
#  'PLAYER NAME',
#  'AGE',
#  'COUNTRY',
#  'TEAM',
#  'PLAYING ROLE',
#  'T-RUNS',
#  'T-WKTS',
#  'ODI-RUNS-S',
#  'ODI-SR-B',
#  'ODI-WKTS',
#  'ODI-SR-BL',
#  'CAPTAINCY EXP',
#  'RUNS-S',
#  'HS',
#  'AVE',
#  'SR-B',
#  'SIXERS',
#  'RUNS-C',
#  'WKTS',
#  'AVE-BL',
#  'ECON',
#  'SR-BL',
#  'AUCTION YEAR',
#  'BASE PRICE',
#  'SOLD PRICE']

# %%
ipl_auction_df.head(100)
# Out:
#     Sl.NO.    PLAYER NAME  AGE COUNTRY  ...  SR-BL AUCTION YEAR  BASE PRICE  \
# 0        1    Abdulla, YA    2      SA  ...  13.93         2009       50000
# 1        2   Abdur Razzak    2     BAN  ...   0.00         2008       50000
# 2        3    Agarkar, AB    2     IND  ...  24.90         2008      200000
# 3        4      Ashwin, R    1     IND  ...  22.14         2011      100000
# 4        5   Badrinath, S    2     IND  ...   0.00         2011      100000
# ..     ...            ...  ...     ...  ...    ...          ...         ...
# 95      96      Sharma, I    1     IND  ...  23.61         2008      150000
# 96      97      Sharma, J    2     IND  ...  21.33         2008      100000
# 97      98     Sharma, RG    1     IND  ...  21.86         2008      150000
# 98      99  Shoaib Akhtar    3     PAK  ...   8.40         2008      250000
# 99     100   Shoaib Malik    2     PAK  ...  25.50         2008      300000
#
#     SOLD PRICE
# 0        50000
# 1        50000
# ...

# %%
ipl_auction_df.head(10).transpose()
# Out:
#                          0             1            2          3  ...  \
# Sl.NO.                   1             2            3          4  ...
# PLAYER NAME    Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R  ...
# AGE                      2             2            2          1  ...
# COUNTRY                 SA           BAN          IND        IND  ...
# TEAM                  KXIP           RCB          KKR        CSK  ...
# PLAYING ROLE    Allrounder        Bowler       Bowler     Bowler  ...
# T-RUNS                   0           214          571        284  ...
# T-WKTS                   0            18           58         31  ...
# ODI-RUNS-S               0           657         1269        241  ...
# ODI-SR-B                 0         71.41        80.62      84.56  ...
# ODI-WKTS                 0           185          288         51  ...
# ODI-SR-BL                0          37.6         32.9       36.8  ...
# ...

# %%
ipl_auction_df[0:5]
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  ...  SR-BL AUCTION YEAR  BASE PRICE  \
# 0       1   Abdulla, YA    2      SA  ...  13.93         2009       50000
# 1       2  Abdur Razzak    2     BAN  ...   0.00         2008       50000
# 2       3   Agarkar, AB    2     IND  ...  24.90         2008      200000
# 3       4     Ashwin, R    1     IND  ...  22.14         2011      100000
# 4       5  Badrinath, S    2     IND  ...   0.00         2011      100000
#
#    SOLD PRICE
# 0       50000
# 1       50000
# 2      350000
# 3      850000
# 4      800000
#
# [5 rows x 26 columns]

# %%
ipl_auction_df[-5:]
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY  ...  SR-BL AUCTION YEAR  BASE PRICE  \
# 125     126     Yadav, AS    2     IND  ...   0.00         2010       50000
# 126     127   Younis Khan    2     PAK  ...   0.00         2008      225000
# 127     128  Yuvraj Singh    2     IND  ...  21.13         2011      400000
# 128     129   Zaheer Khan    2     IND  ...  21.26         2008      200000
# 129     130    Zoysa, DNT    2      SL  ...  33.00         2008      100000
#
#      SOLD PRICE
# 125      750000
# 126      225000
# 127     1800000
# 128      450000
# 129      110000
#
# [5 rows x 26 columns]

# %%
ipl_auction_df['PLAYER NAME'].reset_index()[0:5]
# Out:
#    index   PLAYER NAME
# 0      0   Abdulla, YA
# 1      1  Abdur Razzak
# 2      2   Agarkar, AB
# 3      3     Ashwin, R
# 4      4  Badrinath, S

# %%
ipl_auction_df[['PLAYER NAME','AGE','COUNTRY']][0:10]
# Out:
#      PLAYER NAME  AGE COUNTRY
# 0    Abdulla, YA    2      SA
# 1   Abdur Razzak    2     BAN
# 2    Agarkar, AB    2     IND
# 3      Ashwin, R    1     IND
# 4   Badrinath, S    2     IND
# 5     Bailey, GJ    2     AUS
# 6      Balaji, L    2     IND
# 7  Bollinger, DE    2     AUS
# 8       Botha, J    2      SA
# 9    Boucher, MV    2      SA

# %%
ipl_auction_df.iloc[4:9,1:4]
# Out:
#      PLAYER NAME  AGE COUNTRY
# 4   Badrinath, S    2     IND
# 5     Bailey, GJ    2     AUS
# 6      Balaji, L    2     IND
# 7  Bollinger, DE    2     AUS
# 8       Botha, J    2      SA

# %%
ipl_auction_df.COUNTRY.value_counts()
# Out:
# IND    53
# AUS    22
# SA     16
# SL     12
# PAK     9
# NZ      7
# WI      6
# ENG     3
# BAN     1
# ZIM     1
# Name: COUNTRY, dtype: int64

# %%
ipl_auction_df.COUNTRY.value_counts(normalize=True)*100
# Out:
# IND    40.769231
# AUS    16.923077
# SA     12.307692
# SL      9.230769
# PAK     6.923077
# NZ      5.384615
# WI      4.615385
# ENG     2.307692
# BAN     0.769231
# ZIM     0.769231
# Name: COUNTRY, dtype: float64

# %%
pd.crosstab(ipl_auction_df['AGE'],ipl_auction_df['PLAYING ROLE'])
# Out:
# PLAYING ROLE  Allrounder  Batsman  Bowler  W. Keeper
# AGE
# 1                      4        5       7          0
# 2                     25       21      29         11
# 3                      6       13       8          1

# %%
# Sorting DataFrames by Column values:  sort_values()

ipl_auction_df[['PLAYER NAME','SOLD PRICE']].sort_values('SOLD PRICE')[0:10]
# Out:
#         PLAYER NAME  SOLD PRICE
# 73       Noffke, AA       20000
# 46      Kamran Khan       24000
# 0       Abdulla, YA       50000
# 1      Abdur Razzak       50000
# 118   Van der Merwe       50000
# 5        Bailey, GJ       50000
# 85   Pomersbach, LA       50000
# 34    Henriques, MC       50000
# 61     McDonald, AB       80000
# 78     Pankaj Singh       95000

# %%
ipl_auction_df[['PLAYER NAME','SOLD PRICE']].sort_values('SOLD PRICE',ascending = False)[0:10]
# Out:
#        PLAYER NAME  SOLD PRICE
# 93       Sehwag, V     1800000
# 127   Yuvraj Singh     1800000
# 50        Kohli, V     1800000
# 111  Tendulkar, SR     1800000
# 113     Tiwary, SS     1600000
# 83   Pietersen, KP     1550000
# 23     Flintoff, A     1550000
# 15       Dhoni, MS     1500000
# 108     Symonds, A     1350000
# 110   Taylor, LRPL     1000000

# %%
# create new columns 
ipl_auction_df['Premium'] = ipl_auction_df['SOLD PRICE']-ipl_auction_df['BASE PRICE']

# %%
ipl_auction_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
ipl_auction_df[['PLAYER NAME','BASE PRICE','COUNTRY','SOLD PRICE','Premium']][0:5]
# Out:
#     PLAYER NAME  BASE PRICE COUNTRY  SOLD PRICE  Premium
# 0   Abdulla, YA       50000      SA       50000        0
# 1  Abdur Razzak       50000     BAN       50000        0
# 2   Agarkar, AB      200000     IND      350000   150000
# 3     Ashwin, R      100000     IND      850000   750000
# 4  Badrinath, S      100000     IND      800000   700000

# %%
# Grouping and Aggregating
ipl_auction_df.groupby('AGE')['SOLD PRICE'].mean()
# Out:
# AGE
# 1    720250.000000
# 2    484534.883721
# 3    520178.571429
# Name: SOLD PRICE, dtype: float64

# %%
Soldprice_by_age = ipl_auction_df.groupby('AGE')['SOLD PRICE'].mean().reset_index()

# %%
Soldprice_by_age_role = ipl_auction_df.groupby(['AGE','PLAYING ROLE'])['SOLD PRICE'].mean().reset_index()

# %%
print(Soldprice_by_age_role)
# Out:
#     AGE PLAYING ROLE    SOLD PRICE
# 0     1   Allrounder  5.875000e+05
# 1     1      Batsman  1.110000e+06
# 2     1       Bowler  5.177143e+05
# 3     2   Allrounder  4.494000e+05
# 4     2      Batsman  6.547619e+05
# 5     2       Bowler  3.979310e+05
# 6     2    W. Keeper  4.677273e+05
# 7     3   Allrounder  7.666667e+05
# 8     3      Batsman  4.576923e+05
# 9     3       Bowler  4.143750e+05
# 10    3    W. Keeper  7.000000e+05

# %%
Soldprice_Comparison = Soldprice_by_age_role.merge(Soldprice_by_age, on = 'AGE', how='outer')

# %%
Soldprice_Comparison
# Out:
#     AGE PLAYING ROLE  SOLD PRICE_x   SOLD PRICE_y
# 0     1   Allrounder  5.875000e+05  720250.000000
# 1     1      Batsman  1.110000e+06  720250.000000
# 2     1       Bowler  5.177143e+05  720250.000000
# 3     2   Allrounder  4.494000e+05  484534.883721
# 4     2      Batsman  6.547619e+05  484534.883721
# 5     2       Bowler  3.979310e+05  484534.883721
# 6     2    W. Keeper  4.677273e+05  484534.883721
# 7     3   Allrounder  7.666667e+05  520178.571429
# 8     3      Batsman  4.576923e+05  520178.571429
# 9     3       Bowler  4.143750e+05  520178.571429
# 10    3    W. Keeper  7.000000e+05  520178.571429

# %%
Soldprice_Comparison.rename(columns = {'SOLD PRICE_x': 'SOLD PRICE_AGE_ROLE', 'SOLD PRICE_y': 'SOLD PRICE_AGE'}, inplace= True)

# %%
Soldprice_Comparison.head(5)
# Out:
#    AGE PLAYING ROLE  SOLD PRICE_AGE_ROLE  SOLD PRICE_AGE
# 0    1   Allrounder         5.875000e+05   720250.000000
# 1    1      Batsman         1.110000e+06   720250.000000
# 2    1       Bowler         5.177143e+05   720250.000000
# 3    2   Allrounder         4.494000e+05   484534.883721
# 4    2      Batsman         6.547619e+05   484534.883721

# %%
# Filtering Records based on Condition

ipl_auction_df[ipl_auction_df['SIXERS'] > 60][['PLAYER NAME','COUNTRY','SIXERS']]
# Out:
#        PLAYER NAME COUNTRY  SIXERS
# 15       Dhoni, MS     IND      64
# 26       Gayle, CH      WI     129
# 28   Gilchrist, AC     AUS      86
# 82      Pathan, YK     IND      81
# 88       Raina, SK     IND      97
# 93       Sehwag, V     IND      79
# 97      Sharma, RG     IND      82
# 127   Yuvraj Singh     IND      67

# %%
ipl_auction_df.drop('Sl.NO.',inplace = True, axis =1)

# %%
ipl_auction_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PLAYER NAME    130 non-null    object
#  1   AGE            130 non-null    int64
#  2   COUNTRY        130 non-null    object
#  3   TEAM           130 non-null    object
#  4   PLAYING ROLE   130 non-null    object
#  5   T-RUNS         130 non-null    int64
#  6   T-WKTS         130 non-null    int64
#  7   ODI-RUNS-S     130 non-null    int64
#  8   ODI-SR-B       130 non-null    float64
#  9   ODI-WKTS       130 non-null    int64
#  10  ODI-SR-BL      130 non-null    float64
#  11  CAPTAINCY EXP  130 non-null    int64
#  12  RUNS-S         130 non-null    int64
#  13  HS             130 non-null    int64
#  14  AVE            130 non-null    float64
#  15  SR-B           130 non-null    float64
#  16  SIXERS         130 non-null    int64
# ...

# %%
ipl_auction_df.columns
# Out:
# Index(['PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE', 'T-RUNS',
#        'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE', 'Premium'],
#       dtype='object')

# %%
# Explaoration of Data using Visualization 
#https://matplotlib.org/
# https://seaborn.pydata.org/

import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline

# %%
# 1. Barchart
sn.barplot(x = 'AGE', y  = 'SOLD PRICE' , data = Soldprice_by_age);

# %%
sn.barplot(x = 'AGE', y  = 'SOLD PRICE_AGE_ROLE', hue='PLAYING ROLE' , data = Soldprice_Comparison);

# %%
# 2. Histogram 

plt.hist(ipl_auction_df['SOLD PRICE']);

# %%
plt.hist(ipl_auction_df['SOLD PRICE'], bins=20);

# %%
# 3 Scatter Plot 
ipl_batsman_df = ipl_auction_df[ipl_auction_df['PLAYING ROLE'] =='Batsman']

# %%
plt.scatter(x = ipl_batsman_df.SIXERS, y = ipl_batsman_df['SOLD PRICE']);

# %%
sn.regplot(x ='SIXERS' , y = 'SOLD PRICE', data = ipl_batsman_df );

# %%
# Pair Plot 

influential_features = ['SR-B','AVE', 'SIXERS', 'SOLD PRICE']
sn.pairplot(ipl_auction_df[influential_features], size = 2);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Correlation and heatmap 
ipl_auction_df[influential_features].corr()
# Out:
#                 SR-B       AVE    SIXERS  SOLD PRICE
# SR-B        1.000000  0.583579  0.425394    0.184278
# AVE         0.583579  1.000000  0.705365    0.396519
# SIXERS      0.425394  0.705365  1.000000    0.450609
# SOLD PRICE  0.184278  0.396519  0.450609    1.000000

# %%
sn. heatmap(ipl_auction_df[influential_features].corr(),annot = True);
